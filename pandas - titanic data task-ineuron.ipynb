# %% [markdown]
# # titanic data task

# %%
1 . Find out how many male and female passenger was onboarded .
2. how many survived we have .
3. how many casuality we have 
4 . what is name of a person who is the eldest one . 
5 . how many passenger do we have in first , second and third class 
6. how many person we have whose name starts with "s"
7. try to create a new column which is a summation  of "SibSp" and "parch"
8 . how many person do we have below age of 25 .
9 . how many person died whose age was less then 40 
10 . from a  cabin column seperate text and numeric value .

# %%
import pandas as pd

# %%
titanic=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # 1 . Find out how many male and female passenger was onboarded .

# %%
len(titanic[titanic['Sex']=='male'])
# Out:
# 577

# %%
len(titanic[titanic['Sex']=='female'])
# Out:
# 314

# %%
titanic['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# # 2. how many survived we have .

# %%
titanic['Survived'].value_counts()[1]
# Out:
# 342

# %%
len(titanic[titanic['Survived']== 1])
# Out:
# 342

# %% [markdown]
# # 3. how many casuality we have

# %%
titanic['Survived'].value_counts()[0]
# Out:
# 549

# %% [markdown]
# # 4 . what is name of a person who is the eldest one .

# %%
titanic[titanic['Age']==titanic['Age'].max()]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %% [markdown]
# # 5 . how many passenger do we have in first , second and third class

# %%
len(titanic[titanic['Pclass']==1])
# Out:
# 216

# %%
len(titanic[titanic['Pclass']==2])
# Out:
# 184

# %%
len(titanic[titanic['Pclass']==3])
# Out:
# 491

# %%
titanic['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# # 6. how many person we have whose name starts with "s"

# %%
len(titanic[titanic['Name'].str.startswith('S')])
# Out:
# 86

# %%
len(titanic[titanic['Name'].str[0] == 'S'])
# Out:
# 86

# %% [markdown]
# # 7. try to create a new column which is a summation  of "SibSp" and "parch"

# %%
titanic['sumsibpar']=titanic['SibSp'] + titanic['Parch']

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  sumsibpar
# 0        0         A/5 21171   7.2500   NaN        S          1
# 1        0          PC 17599  71.2833   C85        C          1
# 2        0  STON/O2. 3101282   7.9250   NaN        S          0
# 3        0            113803  53.1000  C123        S          1
# 4        0            373450   8.0500   NaN        S          0
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S          0
# 887      0            112053  30.0000   B42        S          0
# 888      2        W./C. 6607  23.4500   NaN        S          3
# 889      0            111369  30.0000  C148        C          0
# 890      0            370376   7.7500   NaN        Q          0
#
# [891 rows x 13 columns]

# %% [markdown]
# # 8 . how many person do we have below age of 25 .

# %%
len(titanic[titanic['Age']<25])
# Out:
# 278

# %% [markdown]
# # 9 . how many person died whose age was less then 40

# %%
len(titanic[(titanic['Age']<40) &(titanic['Survived']==0)])
# Out:
# 322

# %% [markdown]
# # 10 . from a  cabin column seperate text and numeric value .

# %%
titanic['CabinText']= titanic['Cabin'].str.extract(r'([A-Z]+)', expand=True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  sumsibpar CabinText
# 0        0         A/5 21171   7.2500   NaN        S          1       NaN
# 1        0          PC 17599  71.2833   C85        C          1         C
# 2        0  STON/O2. 3101282   7.9250   NaN        S          0       NaN
# 3        0            113803  53.1000  C123        S          1         C
# 4        0            373450   8.0500   NaN        S          0       NaN
# ..     ...               ...      ...   ...      ...        ...       ...
# 886      0            211536  13.0000   NaN        S          0       NaN
# 887      0            112053  30.0000   B42        S          0         B
# 888      2        W./C. 6607  23.4500   NaN        S          3       NaN
# 889      0            111369  30.0000  C148        C          0         C
# 890      0            370376   7.7500   NaN        Q          0       NaN
#
# [891 rows x 14 columns]

# %%
titanic['CabinNumeric']= titanic['Cabin'].str.extract(r'([0-9]+)', expand=True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  sumsibpar CabinText  \
# 0        0         A/5 21171   7.2500   NaN        S          1       NaN
# 1        0          PC 17599  71.2833   C85        C          1         C
# 2        0  STON/O2. 3101282   7.9250   NaN        S          0       NaN
# 3        0            113803  53.1000  C123        S          1         C
# 4        0            373450   8.0500   NaN        S          0       NaN
# ..     ...               ...      ...   ...      ...        ...       ...
# 886      0            211536  13.0000   NaN        S          0       NaN
# 887      0            112053  30.0000   B42        S          0         B
# 888      2        W./C. 6607  23.4500   NaN        S          3       NaN
# 889      0            111369  30.0000  C148        C          0         C
# 890      0            370376   7.7500   NaN        Q          0       NaN
#
#     CabinNumeric
# 0            NaN
# 1             85
# 2            NaN
# 3            123
# 4            NaN
# ..           ...
# 886          NaN
# 887           42
# 888          NaN
# 889          148
# 890          NaN
#
# [891 rows x 15 columns]
